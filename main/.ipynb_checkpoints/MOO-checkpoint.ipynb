# %%
import os
import sys

sys.path.append(os.path.abspath(os.path.join('..'))) # imports top level

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import display
import scipy
from collections import defaultdict

import random

# %%
from joblib import load

# %%
pop = load("trained_population_121e_p_ksym_kquar.joblib")

# %%
pop = np.asarray(pop)

# %%
scores = []
k_sym = []
k_quarter = []
p_margin = []
k_fa_max = []

for i in pop:
    if not i["core_burnup"] <= 30:
        continue
    scores.append(
        i["fitness_score"]
    )
    k_sym.append(
        i["k_sym"]
    )
    k_quarter.append(
        i["k_quarter"]
    )
    p_margin.append(
        i["p_margin"]
    )
    k_fa_max.append(
        i["k_fa_max"]
    )

# %%
k_quarter=np.array(k_quarter)
k_sym=np.array(k_sym)
scores=np.array(scores)
p_margin=np.array(p_margin)
k_fa_max=np.array(k_fa_max)

# %%
sns.scatterplot(x=k_sym, y=k_quarter)
# Out:
# <Axes: >

# %%
sns.scatterplot(x=p_margin, y=k_fa_max)
# Out:
# <Axes: >

# %%
sns.scatterplot(x=scores, y=k_sym)
sns.scatterplot(x=scores, y=k_quarter)
# Out:
# <Axes: >
