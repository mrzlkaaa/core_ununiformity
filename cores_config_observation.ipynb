# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("input.xlsx")

# %%
df.columns
# Out:
# Index(['Name', 'pmar', '7-6_s', '7-5_s', '7-4_s', '7-3_s', '6-6_s', '6-5_s',
#        '6-4_s', '6-3_s', '5-6_s', '5-3_s', '4-6_s', '4-3_s', '3-6_s', '3-5_s',
#        '3-4_s', '3-3_s', '2-6_s', '2-5_s', '2-4_s', '2-3_s', '7-6', '7-5',
#        '7-4', '7-3', '6-6', '6-5', '6-4', '6-3', '5-6', '5-3', '4-6', '4-3',
#        '3-6', '3-5', '3-4', '3-3', '2-6', '2-5', '2-4', '2-3', 'Notes'],
#       dtype='object')

# %%
cols_s = [
    "7-6_s",	"7-5_s",	"7-4_s",	"7-3_s",	
    "6-6_s",	"6-5_s",	"6-4_s",	"6-3_s",	
    "5-6_s",	"5-3_s",	"4-6_s",	"4-3_s",
    "3-6_s",	"3-5_s",	"3-4_s",	"3-3_s",
    "2-6_s",	"2-5_s",	"2-4_s",	"2-3_s"
]

cols = [
    "7-6",	"7-5",	"7-4",	"7-3",	
    "6-6",	"6-5",	"6-4",	"6-3",	
    "5-6",	"5-3",	"4-6",	"4-3",
    "3-6",	"3-5",	"3-4",	"3-3",
    "2-6",	"2-5",	"2-4",	"2-3"
]

# %%
left_side_s = [
    "7-6_s", "7-5_s",
    "6-6_s", "6-5_s",
    "5-6_s", "4-6_s",
    "3-6_s", "3-5_s",
    "2-6_s", "2-5_s"
]

right_side_s = [
    "7-4_s", "7-3_s",
    "6-4_s", "6-3_s",
    "5-3_s", "4-3_s",
    "3-4_s", "3-3_s",
    "2-4_s", "2-3_s"
]

# %%
left_side = [
    "7-6", "7-5",
    "6-6", "6-5",
    "5-6", "4-6",
    "3-6", "3-5",
    "2-6", "2-5"
]

right_side = [
    "7-4", "7-3",
    "6-4", "6-3",
    "5-3", "4-3",
    "3-4", "3-3",
    "2-4", "2-3"
]

# %%
df["right_side"] = df.loc[:, right_side].mean(axis=1)
df["left_side"] = df.loc[:, left_side].mean(axis=1)

df["right_side_s"] = df.loc[:, right_side_s].mean(axis=1)
df["left_side_s"] = df.loc[:, left_side_s].mean(axis=1)

# %%
sns.scatterplot(x=df["pmar"], y=df.loc[:, cols].mean(axis=1))
# Out:
# /home/mrzlka/.pyenv/versions/3.10.0/envs/core_uniniformity/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/mrzlka/.pyenv/versions/3.10.0/envs/core_uniniformity/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='pmar'>

# %%
sns.scatterplot(x=df["pmar"], y=df["right_side"][df["right_side"] < df["left_side"]], label="right")
sns.scatterplot(x=df["pmar"], y=df["left_side"][df["right_side"] < df["left_side"]], label="left")
# Out:
# /home/mrzlka/.pyenv/versions/3.10.0/envs/core_uniniformity/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/mrzlka/.pyenv/versions/3.10.0/envs/core_uniniformity/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/mrzlka/.pyenv/versions/3.10.0/envs/core_uniniformity/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
sns.histplot(df.loc[:, cols].mean(axis=1), bins=10)
# Out:
# /home/mrzlka/.pyenv/versions/3.10.0/envs/core_uniniformity/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/mrzlka/.pyenv/versions/3.10.0/envs/core_uniniformity/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Count'>

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.drop(["Name", "Notes"], axis=1).corr())
# Out:
# <Axes: >
